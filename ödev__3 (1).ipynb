cevaplar =["B", "C", "A","B","C","A","B","C","A","C","B","B","A","A","B","b","A","D"]
doğrular =[]
yanlışlar=[]
import random
import time
import numpy as np
from timeit import default_timer as timer
from numba import vectorize


  
#liste=random.choices(sorular,weights=None,k=3)
liste=[]

#for i in range(10):
 # a=random.randint(0,20)
  #liste.append(sorular[a],cevaplar[a])
print("Bilgi yarışmasıan hoş geldin...!:)")
print(50*"*")
ad = input("Adını yaz..:) ")

start = timer()

while sayac<10:
  sıra=random.randint(0,20)
  if sıra not in sorular:
    print(sayac+1,")",sorular[sıra-1])
    x=5
    sayac+=1
    while x >=0:
      print(x)
      x = x-1
      time.sleep(1)
    cevap = input("Cevap şıkkınızı giriniz: ")
    
    if cevap.upper() == cevaplar[sıra-1]:
      puan +=10
      print("Cevabın doğru",ad," tebrikler, Yeni puanın:", puan)
      doğrular.append(sorular[sıra-1])

    else:
      print("Cevabın hatalı!",ad," Lütfen dikkatli ol...:)")
      print("doğru cavap....:",cevaplar[sıra-1])
      yanlışlar.append(sorular[sıra-1])
    

topd=len(doğrular)
topy=len(yanlışlar)
print(50*"*")
print(f"Yarışama bitti. {ad}. Toplam Puanın: {puan} ")
duration = timer() - start
round(duration)
print("yarışmayı şu kadar sürede bitirdiniz...=",duration)
print(topd,": toplam doğru sayınız..",doğrular,":doğru yaptığınız sorular")
print(topy,":yanlışsayınız...",yanlışlar,".yanlış yaptığınız sorular")
# Out:
# Bilgi yarışmasıan hoş geldin...!:)
# **************************************************
# Adını yaz..:) salih
# 1 ) Romen Rakamında Hangi Sayı Yoktur?
#  A) 0 B) 50 C) 100 D) 1000
# 5
# 4
# 3
# 2
# 1
# 0
# Cevap şıkkınızı giriniz: a
# Cevabın hatalı! salih  Lütfen dikkatli ol...:)
# doğru cavap....: C
# 2 )  Tsunami Felaketinde En Fazla Zarar Gören Güney Asya Ülkesi Aşağıdakilerden Hangisidir?
#  A) Endonezya B) Srilanka C) Tayland D) Hindistan
# 5
# 4
# 3
# 2
# 1
# 0
# Cevap şıkkınızı giriniz: b
# Cevabın hatalı! salih  Lütfen dikkatli ol...:)
# doğru cavap....: A
# 3 )  Mustafa Kemal Atatürk’ün Nüfusa Kayıtlı Olduğu İl Hangisidir?
#  A) Bursa B) Ankara C) İstanbul D) Gaziantep
# 5
# 4
# 3
# 2
# 1
# 0
# Cevap şıkkınızı giriniz: a
# Cevabın hatalı! salih  Lütfen dikkatli ol...:)
# doğru cavap....: C
# 4 ) Türkiyede erozyonla mücadele için kurulan kuruluşun ismi nedir?
#  A)AFAD  B)FBI  C)TEMA  D)Yeşilay
# 5
# 4
# 3
# 2
# 1
# 0
# Cevap şıkkınızı giriniz: c
# ...
